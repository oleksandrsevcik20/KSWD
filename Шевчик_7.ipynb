# %% [markdown]
# <a href="https://colab.research.google.com/github/oleksandrsevcik20/KSWD/blob/main/%D0%A8%D0%B5%D0%B2%D1%87%D0%B8%D0%BA_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
from tqdm import tqdm

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import torchvision
import torch
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import transforms, datasets

# %%
data_dir = 'data'

train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

print(train_dataset)
type(train_dataset)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 49.8MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 2.77MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 12.4MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.77MB/s]
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
# torchvision.datasets.mnist.MNIST

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))
for ax in axs.flatten():
    img, label = random.choice(train_dataset)
    ax.imshow(np.array(img), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# %%
import torch
from torchvision import datasets, transforms

class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.mean = mean
        self.std = std

    def __call__ (self, tensor):
        noise = torch.randn(tensor.size()) * self.std + self.mean
        return tensor + noise

transform_with_noise = transforms.Compose([
    transforms. ToTensor(),
    AddGaussianNoise (mean=0.0, std=0.1),
    transforms.Normalize((0.5,), (0.5,))
])

# Завантажуємо тренувальний та тестовий датасети з шумом
train_dataset = datasets.MNIST (root='path_to_data', train=True, download=True, transform=transform_with_noise)
test_dataset = datasets. MNIST (root='path_to_data', train=False, download=True, transform=transform_with_noise)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 56.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.78MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 12.6MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.14MB/s]

# %%
fig, axs = plt.subplots(5, 5, figsize=(6,6))

for ax in axs.flatten():
    img, label = random.choice(train_dataset)

    img = img *0.5 + 0.5

    ax.imshow(np.array(img).squeeze(), cmap='gist_gray')
    ax.set_title('Label: %d' % label)
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
m=len(train_dataset)
train_data, val_data = random_split(train_dataset, [int(len(train_dataset)*0.8), int(m*0.2)])

# %%
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):
    def __init__(self, encoded_space_dim):
        super().__init__()

        # Convolutional section
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            nn.ReLU(True)
        )

        # Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        # Linear section
        self.encoder_lin = nn.Sequential(
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            nn.Linear(128, encoded_space_dim)
        )

    def forward(self, x):
        x = self.encoder_cnn(x)
        x = self.flatten(x)
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, encoded_space_dim, fc2_input_dim=128):
        super().__init__()

        # Linear section
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 7 * 7 * 16),  # Змінено для 7x7x16
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(16, 7, 7))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(16, 8, 4, stride=2, padding=1),  # 7x7 -> 14x14
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 4, stride=2, padding=1)  # 14x14 -> 28x28
        )

    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
# Set the random seed for reproducible results
torch.manual_seed(42)

# Initialize the two networks
encoded_space_dim = 4  # Розмір закодованого простору
encoder = Encoder(encoded_space_dim=encoded_space_dim)
decoder = Decoder(encoded_space_dim=encoded_space_dim)

# %%
img, _ = test_dataset[0]
img = img.unsqueeze(0) # Add the batch dimension in the first axis
print('Original image shape:', img.shape)

# Encode the image
img_enc = encoder(img)
print('Encoded image shape:', img_enc.shape)

# Decode the image
dec_img = decoder(img_enc)
print('Decoded image shape:', dec_img.shape)
# Out:
# Original image shape: torch.Size([1, 1, 28, 28])
# Encoded image shape: torch.Size([1, 4])
# Decoded image shape: torch.Size([1, 1, 28, 28])

# %%
# Define the loss function
loss_fn = torch.nn.MSELoss()

# Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
# Out:
# Selected device: cpu
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
decoder.to(device)
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=784, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(16, 7, 7))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(8, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch, _ in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = image_batch.to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch, _ in dataloader:
            # Move tensor to the proper device
            image_batch = image_batch.to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label)
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=5):
    plt.figure(figsize=(10,4.5))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        img = test_dataset[i][0].unsqueeze(0).to(device)
        encoder.eval()
        decoder.eval()
        with torch.no_grad():
            rec_img  = decoder(encoder(img))
        plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Original images')
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == n//2:
            ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 20
history={'train_loss':[],'val_loss':[]}

for epoch in range(num_epochs):
    train_loss = train_epoch(encoder,decoder,device,train_loader,loss_fn,optim)
    val_loss = test_epoch(encoder,decoder,device,valid_loader,loss_fn)

    print('\\n EPOCH {}/{} \\t train loss {:.3f} \\t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    plot_ae_outputs(encoder,decoder,n=5)
# Out:
# \t partial train loss (single batch): 2.247483
# \t partial train loss (single batch): 2.202210
# \t partial train loss (single batch): 2.186438
# \t partial train loss (single batch): 2.161269
# \t partial train loss (single batch): 2.142808
# \t partial train loss (single batch): 2.122615
# \t partial train loss (single batch): 2.118167
# \t partial train loss (single batch): 2.092182
# \t partial train loss (single batch): 2.073634
# \t partial train loss (single batch): 2.071723
# \t partial train loss (single batch): 2.054825
# \t partial train loss (single batch): 2.067038
# \t partial train loss (single batch): 2.023010
# \t partial train loss (single batch): 2.025921
# \t partial train loss (single batch): 2.012032
# \t partial train loss (single batch): 2.013938
# \t partial train loss (single batch): 1.999041
# \t partial train loss (single batch): 1.993212
# \t partial train loss (single batch): 1.993933
# \t partial train loss (single batch): 1.968479
# \t partial train loss (single batch): 1.954957
# \t partial train loss (single batch): 1.948595
# \t partial train loss (single batch): 1.943974
# \t partial train loss (single batch): 1.937332
# \t partial train loss (single batch): 1.935063
# \t partial train loss (single batch): 1.914566
# \t partial train loss (single batch): 1.907331
# \t partial train loss (single batch): 1.905948
# \t partial train loss (single batch): 1.889541
# \t partial train loss (single batch): 1.884366
# \t partial train loss (single batch): 1.889516
# \t partial train loss (single batch): 1.869959
# \t partial train loss (single batch): 1.858616
# \t partial train loss (single batch): 1.857464
# \t partial train loss (single batch): 1.855515
# \t partial train loss (single batch): 1.842220
# \t partial train loss (single batch): 1.836931
# \t partial train loss (single batch): 1.824521
# \t partial train loss (single batch): 1.820031
# \t partial train loss (single batch): 1.813067
# \t partial train loss (single batch): 1.789219
# \t partial train loss (single batch): 1.789977
# \t partial train loss (single batch): 1.774899
# \t partial train loss (single batch): 1.768079
# \t partial train loss (single batch): 1.769485
# \t partial train loss (single batch): 1.765093
# \t partial train loss (single batch): 1.747279
# \t partial train loss (single batch): 1.753965
# \t partial train loss (single batch): 1.731383
# \t partial train loss (single batch): 1.720868
# \t partial train loss (single batch): 1.723063
# \t partial train loss (single batch): 1.718877
# \t partial train loss (single batch): 1.701676
# \t partial train loss (single batch): 1.698755
# \t partial train loss (single batch): 1.692779
# \t partial train loss (single batch): 1.693959
# \t partial train loss (single batch): 1.683035
# \t partial train loss (single batch): 1.666940
# \t partial train loss (single batch): 1.659943
# \t partial train loss (single batch): 1.653882
# \t partial train loss (single batch): 1.648787
# \t partial train loss (single batch): 1.635011
# \t partial train loss (single batch): 1.628109
# \t partial train loss (single batch): 1.621238
# \t partial train loss (single batch): 1.627886
# \t partial train loss (single batch): 1.609277
# \t partial train loss (single batch): 1.596754
# \t partial train loss (single batch): 1.597863
# \t partial train loss (single batch): 1.595421
# \t partial train loss (single batch): 1.584539
# \t partial train loss (single batch): 1.569859
# \t partial train loss (single batch): 1.570949
# \t partial train loss (single batch): 1.557495
# \t partial train loss (single batch): 1.553742
# \t partial train loss (single batch): 1.540603
# \t partial train loss (single batch): 1.533611
# \t partial train loss (single batch): 1.526019
# \t partial train loss (single batch): 1.523800
# \t partial train loss (single batch): 1.515926
# \t partial train loss (single batch): 1.511601
# \t partial train loss (single batch): 1.514537
# \t partial train loss (single batch): 1.487542
# \t partial train loss (single batch): 1.496423
# \t partial train loss (single batch): 1.480347
# \t partial train loss (single batch): 1.482654
# \t partial train loss (single batch): 1.477809
# \t partial train loss (single batch): 1.468903
# \t partial train loss (single batch): 1.460754
# \t partial train loss (single batch): 1.451002
# \t partial train loss (single batch): 1.455798
# \t partial train loss (single batch): 1.446401
# \t partial train loss (single batch): 1.434193
# \t partial train loss (single batch): 1.434386
# \t partial train loss (single batch): 1.423743
# \t partial train loss (single batch): 1.420500
# \t partial train loss (single batch): 1.419089
# \t partial train loss (single batch): 1.406528
# \t partial train loss (single batch): 1.415142
# \t partial train loss (single batch): 1.404018
# \t partial train loss (single batch): 1.402406
# \t partial train loss (single batch): 1.388915
# \t partial train loss (single batch): 1.386259
# \t partial train loss (single batch): 1.380007
# \t partial train loss (single batch): 1.374104
# \t partial train loss (single batch): 1.368630
# \t partial train loss (single batch): 1.369428
# \t partial train loss (single batch): 1.362534
# \t partial train loss (single batch): 1.355092
# \t partial train loss (single batch): 1.352610
# \t partial train loss (single batch): 1.347790
# \t partial train loss (single batch): 1.340074
# \t partial train loss (single batch): 1.344164
# \t partial train loss (single batch): 1.334744
# \t partial train loss (single batch): 1.330124
# \t partial train loss (single batch): 1.321352
# \t partial train loss (single batch): 1.320919
# \t partial train loss (single batch): 1.315182
# \t partial train loss (single batch): 1.305734
# \t partial train loss (single batch): 1.303021
# \t partial train loss (single batch): 1.304314
# \t partial train loss (single batch): 1.300037
# \t partial train loss (single batch): 1.299602
# \t partial train loss (single batch): 1.291326
# \t partial train loss (single batch): 1.288754
# \t partial train loss (single batch): 1.282273
# \t partial train loss (single batch): 1.274301
# \t partial train loss (single batch): 1.278270
# \t partial train loss (single batch): 1.270286
# \t partial train loss (single batch): 1.262069
# \t partial train loss (single batch): 1.267481
# \t partial train loss (single batch): 1.261788
# \t partial train loss (single batch): 1.261087
# \t partial train loss (single batch): 1.256475
# \t partial train loss (single batch): 1.255894
# \t partial train loss (single batch): 1.252486
# \t partial train loss (single batch): 1.252260
# \t partial train loss (single batch): 1.242877
# \t partial train loss (single batch): 1.242311
# \t partial train loss (single batch): 1.231273
# \t partial train loss (single batch): 1.230722
# \t partial train loss (single batch): 1.232697
# \t partial train loss (single batch): 1.226041
# \t partial train loss (single batch): 1.223353
# \t partial train loss (single batch): 1.222425
# \t partial train loss (single batch): 1.217590
# \t partial train loss (single batch): 1.219764
# \t partial train loss (single batch): 1.214934
# \t partial train loss (single batch): 1.211446
# \t partial train loss (single batch): 1.211605
# \t partial train loss (single batch): 1.206619
# \t partial train loss (single batch): 1.204656
# \t partial train loss (single batch): 1.198718
# \t partial train loss (single batch): 1.191156
# \t partial train loss (single batch): 1.189525
# \t partial train loss (single batch): 1.189834
# \t partial train loss (single batch): 1.186451
# \t partial train loss (single batch): 1.177518
# \t partial train loss (single batch): 1.181455
# \t partial train loss (single batch): 1.180996
# \t partial train loss (single batch): 1.180314
# \t partial train loss (single batch): 1.174040
# \t partial train loss (single batch): 1.172375
# \t partial train loss (single batch): 1.173987
# \t partial train loss (single batch): 1.169043
# \t partial train loss (single batch): 1.165092
# \t partial train loss (single batch): 1.168126
# \t partial train loss (single batch): 1.161065
# \t partial train loss (single batch): 1.163810
# \t partial train loss (single batch): 1.159914
# \t partial train loss (single batch): 1.153897
# \t partial train loss (single batch): 1.152866
# \t partial train loss (single batch): 1.150820
# \t partial train loss (single batch): 1.152894
# \t partial train loss (single batch): 1.140368
# \t partial train loss (single batch): 1.144232
# \t partial train loss (single batch): 1.140165
# \t partial train loss (single batch): 1.140753
# \t partial train loss (single batch): 1.145551
# \t partial train loss (single batch): 1.136710
# \t partial train loss (single batch): 1.136310
# \t partial train loss (single batch): 1.132333
# \t partial train loss (single batch): 1.131623
# \t partial train loss (single batch): 1.131930
# \t partial train loss (single batch): 1.127709
# \t partial train loss (single batch): 1.127036
# \t partial train loss (single batch): 1.125182
# \t partial train loss (single batch): 1.120396
# \t partial train loss (single batch): 1.117653
# \n EPOCH 1/20 \t train loss 1.504 \t val loss 1.118
# \t partial train loss (single batch): 1.125620
# \t partial train loss (single batch): 1.119161
# \t partial train loss (single batch): 1.120412
# \t partial train loss (single batch): 1.116509
# \t partial train loss (single batch): 1.114374
# \t partial train loss (single batch): 1.111113
# \t partial train loss (single batch): 1.113867
# \t partial train loss (single batch): 1.106499
# \t partial train loss (single batch): 1.104266
# \t partial train loss (single batch): 1.105983
# \t partial train loss (single batch): 1.101968
# \t partial train loss (single batch): 1.110740
# \t partial train loss (single batch): 1.096929
# \t partial train loss (single batch): 1.099329
# \t partial train loss (single batch): 1.098509
# \t partial train loss (single batch): 1.098898
# \t partial train loss (single batch): 1.097895
# \t partial train loss (single batch): 1.095518
# \t partial train loss (single batch): 1.096738
# \t partial train loss (single batch): 1.090091
# \t partial train loss (single batch): 1.089246
# \t partial train loss (single batch): 1.089955
# \t partial train loss (single batch): 1.089488
# \t partial train loss (single batch): 1.089430
# \t partial train loss (single batch): 1.088466
# \t partial train loss (single batch): 1.081507
# \t partial train loss (single batch): 1.085352
# \t partial train loss (single batch): 1.083351
# \t partial train loss (single batch): 1.080359
# \t partial train loss (single batch): 1.080855
# \t partial train loss (single batch): 1.083236
# \t partial train loss (single batch): 1.078235
# \t partial train loss (single batch): 1.076260
# \t partial train loss (single batch): 1.076103
# \t partial train loss (single batch): 1.077298
# \t partial train loss (single batch): 1.076195
# \t partial train loss (single batch): 1.075330
# \t partial train loss (single batch): 1.071934
# \t partial train loss (single batch): 1.070445
# \t partial train loss (single batch): 1.072606
# \t partial train loss (single batch): 1.065066
# \t partial train loss (single batch): 1.070065
# \t partial train loss (single batch): 1.064292
# \t partial train loss (single batch): 1.062795
# \t partial train loss (single batch): 1.067334
# \t partial train loss (single batch): 1.065841
# \t partial train loss (single batch): 1.059724
# \t partial train loss (single batch): 1.067284
# \t partial train loss (single batch): 1.059270
# \t partial train loss (single batch): 1.059990
# \t partial train loss (single batch): 1.060096
# \t partial train loss (single batch): 1.061083
# \t partial train loss (single batch): 1.056945
# \t partial train loss (single batch): 1.057444
# \t partial train loss (single batch): 1.058679
# \t partial train loss (single batch): 1.060452
# \t partial train loss (single batch): 1.057792
# \t partial train loss (single batch): 1.053149
# \t partial train loss (single batch): 1.054036
# \t partial train loss (single batch): 1.051420
# \t partial train loss (single batch): 1.052400
# \t partial train loss (single batch): 1.051187
# \t partial train loss (single batch): 1.048327
# \t partial train loss (single batch): 1.049514
# \t partial train loss (single batch): 1.054034
# \t partial train loss (single batch): 1.049080
# \t partial train loss (single batch): 1.045205
# \t partial train loss (single batch): 1.048131
# \t partial train loss (single batch): 1.048408
# \t partial train loss (single batch): 1.047528
# \t partial train loss (single batch): 1.042194
# \t partial train loss (single batch): 1.044320
# \t partial train loss (single batch): 1.042513
# \t partial train loss (single batch): 1.042901
# \t partial train loss (single batch): 1.040105
# \t partial train loss (single batch): 1.037439
# \t partial train loss (single batch): 1.036741
# \t partial train loss (single batch): 1.037260
# \t partial train loss (single batch): 1.036664
# \t partial train loss (single batch): 1.037325
# \t partial train loss (single batch): 1.042453
# \t partial train loss (single batch): 1.033527
# \t partial train loss (single batch): 1.039062
# \t partial train loss (single batch): 1.032579
# \t partial train loss (single batch): 1.035578
# \t partial train loss (single batch): 1.034585
# \t partial train loss (single batch): 1.033481
# \t partial train loss (single batch): 1.032557
# \t partial train loss (single batch): 1.027705
# \t partial train loss (single batch): 1.036004
# \t partial train loss (single batch): 1.032601
# \t partial train loss (single batch): 1.029166
# \t partial train loss (single batch): 1.029367
# \t partial train loss (single batch): 1.026031
# \t partial train loss (single batch): 1.027076
# \t partial train loss (single batch): 1.027590
# \t partial train loss (single batch): 1.023609
# \t partial train loss (single batch): 1.031575
# \t partial train loss (single batch): 1.026988
# \t partial train loss (single batch): 1.028852
# \t partial train loss (single batch): 1.025083
# \t partial train loss (single batch): 1.025158
# \t partial train loss (single batch): 1.022198
# \t partial train loss (single batch): 1.021480
# \t partial train loss (single batch): 1.021762
# \t partial train loss (single batch): 1.023496
# \t partial train loss (single batch): 1.022478
# \t partial train loss (single batch): 1.020327
# \t partial train loss (single batch): 1.019730
# \t partial train loss (single batch): 1.020415
# \t partial train loss (single batch): 1.015283
# \t partial train loss (single batch): 1.022207
# \t partial train loss (single batch): 1.019170
# \t partial train loss (single batch): 1.014971
# \t partial train loss (single batch): 1.014742
# \t partial train loss (single batch): 1.016054
# \t partial train loss (single batch): 1.012955
# \t partial train loss (single batch): 1.009412
# \t partial train loss (single batch): 1.010951
# \t partial train loss (single batch): 1.012866
# \t partial train loss (single batch): 1.012578
# \t partial train loss (single batch): 1.014024
# \t partial train loss (single batch): 1.011697
# \t partial train loss (single batch): 1.011779
# \t partial train loss (single batch): 1.010434
# \t partial train loss (single batch): 1.006072
# \t partial train loss (single batch): 1.010296
# \t partial train loss (single batch): 1.008541
# \t partial train loss (single batch): 1.002266
# \t partial train loss (single batch): 1.005281
# \t partial train loss (single batch): 1.007247
# \t partial train loss (single batch): 1.007488
# \t partial train loss (single batch): 1.005169
# \t partial train loss (single batch): 1.007390
# \t partial train loss (single batch): 1.007299
# \t partial train loss (single batch): 1.007742
# \t partial train loss (single batch): 1.003609
# \t partial train loss (single batch): 1.004884
# \t partial train loss (single batch): 1.000065
# \t partial train loss (single batch): 1.001376
# \t partial train loss (single batch): 1.005577
# \t partial train loss (single batch): 1.000478
# \t partial train loss (single batch): 0.999689
# \t partial train loss (single batch): 1.000107
# \t partial train loss (single batch): 0.999534
# \t partial train loss (single batch): 1.003503
# \t partial train loss (single batch): 1.000353
# \t partial train loss (single batch): 1.000263
# \t partial train loss (single batch): 1.000094
# \t partial train loss (single batch): 1.000763
# \t partial train loss (single batch): 0.998888
# \t partial train loss (single batch): 0.997042
# \t partial train loss (single batch): 0.992921
# \t partial train loss (single batch): 0.994933
# \t partial train loss (single batch): 0.993927
# \t partial train loss (single batch): 0.994235
# \t partial train loss (single batch): 0.991796
# \t partial train loss (single batch): 0.994552
# \t partial train loss (single batch): 0.993431
# \t partial train loss (single batch): 0.995210
# \t partial train loss (single batch): 0.991006
# \t partial train loss (single batch): 0.990276
# \t partial train loss (single batch): 0.993563
# \t partial train loss (single batch): 0.990284
# \t partial train loss (single batch): 0.990406
# \t partial train loss (single batch): 0.990996
# \t partial train loss (single batch): 0.990274
# \t partial train loss (single batch): 0.990608
# \t partial train loss (single batch): 0.990843
# \t partial train loss (single batch): 0.985700
# \t partial train loss (single batch): 0.986095
# \t partial train loss (single batch): 0.990848
# \t partial train loss (single batch): 0.990125
# \t partial train loss (single batch): 0.982009
# \t partial train loss (single batch): 0.987854
# \t partial train loss (single batch): 0.982807
# \t partial train loss (single batch): 0.985063
# \t partial train loss (single batch): 0.990634
# \t partial train loss (single batch): 0.985660
# \t partial train loss (single batch): 0.986653
# \t partial train loss (single batch): 0.984102
# \t partial train loss (single batch): 0.984778
# \t partial train loss (single batch): 0.986005
# \t partial train loss (single batch): 0.984970
# \t partial train loss (single batch): 0.985266
# \t partial train loss (single batch): 0.983208
# \t partial train loss (single batch): 0.981080
# \t partial train loss (single batch): 0.978101
# \n EPOCH 2/20 \t train loss 1.035 \t val loss 0.984
# \t partial train loss (single batch): 0.987707
# \t partial train loss (single batch): 0.980499
# \t partial train loss (single batch): 0.982970
# \t partial train loss (single batch): 0.981950
# \t partial train loss (single batch): 0.979699
# \t partial train loss (single batch): 0.979919
# \t partial train loss (single batch): 0.983361
# \t partial train loss (single batch): 0.980598
# \t partial train loss (single batch): 0.978515
# \t partial train loss (single batch): 0.981657
# \t partial train loss (single batch): 0.978232
# \t partial train loss (single batch): 0.983915
# \t partial train loss (single batch): 0.976088
# \t partial train loss (single batch): 0.979871
# \t partial train loss (single batch): 0.975554
# \t partial train loss (single batch): 0.979936
# \t partial train loss (single batch): 0.979086
# \t partial train loss (single batch): 0.978810
# \t partial train loss (single batch): 0.982142
# \t partial train loss (single batch): 0.976708
# \t partial train loss (single batch): 0.976860
# \t partial train loss (single batch): 0.975828
# \t partial train loss (single batch): 0.977878
# \t partial train loss (single batch): 0.978163
# \t partial train loss (single batch): 0.979024
# \t partial train loss (single batch): 0.974459
# \t partial train loss (single batch): 0.976713
# \t partial train loss (single batch): 0.977346
# \t partial train loss (single batch): 0.975705
# \t partial train loss (single batch): 0.976624
# \t partial train loss (single batch): 0.979582
# \t partial train loss (single batch): 0.976909
# \t partial train loss (single batch): 0.973553
# \t partial train loss (single batch): 0.974678
# \t partial train loss (single batch): 0.979164
# \t partial train loss (single batch): 0.978250
# \t partial train loss (single batch): 0.975512
# \t partial train loss (single batch): 0.974053
# \t partial train loss (single batch): 0.974764
# \t partial train loss (single batch): 0.976236
# \t partial train loss (single batch): 0.971823
# \t partial train loss (single batch): 0.974257
# \t partial train loss (single batch): 0.973011
# \t partial train loss (single batch): 0.970740
# \t partial train loss (single batch): 0.975491
# \t partial train loss (single batch): 0.975013
# \t partial train loss (single batch): 0.972021
# \t partial train loss (single batch): 0.977509
# \t partial train loss (single batch): 0.969223
# \t partial train loss (single batch): 0.971389
# \t partial train loss (single batch): 0.974036
# \t partial train loss (single batch): 0.975671
# \t partial train loss (single batch): 0.971850
# \t partial train loss (single batch): 0.972810
# \t partial train loss (single batch): 0.972983
# \t partial train loss (single batch): 0.976486
# \t partial train loss (single batch): 0.975476
# \t partial train loss (single batch): 0.970283
# \t partial train loss (single batch): 0.974510
# \t partial train loss (single batch): 0.971473
# \t partial train loss (single batch): 0.974403
# \t partial train loss (single batch): 0.970926
# \t partial train loss (single batch): 0.972230
# \t partial train loss (single batch): 0.973171
# \t partial train loss (single batch): 0.975361
# \t partial train loss (single batch): 0.971291
# \t partial train loss (single batch): 0.971305
# \t partial train loss (single batch): 0.972643
# \t partial train loss (single batch): 0.973886
# \t partial train loss (single batch): 0.971323
# \t partial train loss (single batch): 0.970381
# \t partial train loss (single batch): 0.970823
# \t partial train loss (single batch): 0.970604
# \t partial train loss (single batch): 0.969873
# \t partial train loss (single batch): 0.969078
# \t partial train loss (single batch): 0.967126
# \t partial train loss (single batch): 0.969960
# \t partial train loss (single batch): 0.968067
# \t partial train loss (single batch): 0.968778
# \t partial train loss (single batch): 0.970864
# \t partial train loss (single batch): 0.972415
# \t partial train loss (single batch): 0.964967
# \t partial train loss (single batch): 0.970166
# \t partial train loss (single batch): 0.967046
# \t partial train loss (single batch): 0.968170
# \t partial train loss (single batch): 0.970771
# \t partial train loss (single batch): 0.968353
# \t partial train loss (single batch): 0.969902
# \t partial train loss (single batch): 0.966339
# \t partial train loss (single batch): 0.974078
# \t partial train loss (single batch): 0.970611
# \t partial train loss (single batch): 0.967363
# \t partial train loss (single batch): 0.967418
# \t partial train loss (single batch): 0.968155
# \t partial train loss (single batch): 0.968058
# \t partial train loss (single batch): 0.969469
# \t partial train loss (single batch): 0.966265
# \t partial train loss (single batch): 0.971622
# \t partial train loss (single batch): 0.969166
# \t partial train loss (single batch): 0.969556
# \t partial train loss (single batch): 0.968497
# \t partial train loss (single batch): 0.969160
# \t partial train loss (single batch): 0.966645
# \t partial train loss (single batch): 0.966424
# \t partial train loss (single batch): 0.964883
# \t partial train loss (single batch): 0.967047
# \t partial train loss (single batch): 0.968610
# \t partial train loss (single batch): 0.965052
# \t partial train loss (single batch): 0.965402
# \t partial train loss (single batch): 0.967319
# \t partial train loss (single batch): 0.965162
# \t partial train loss (single batch): 0.969376
# \t partial train loss (single batch): 0.967209
# \t partial train loss (single batch): 0.966434
# \t partial train loss (single batch): 0.964614
# \t partial train loss (single batch): 0.966017
# \t partial train loss (single batch): 0.964807
# \t partial train loss (single batch): 0.962457
# \t partial train loss (single batch): 0.959618
# \t partial train loss (single batch): 0.965816
# \t partial train loss (single batch): 0.964366
# \t partial train loss (single batch): 0.966207
# \t partial train loss (single batch): 0.966058
# \t partial train loss (single batch): 0.964135
# \t partial train loss (single batch): 0.964121
# \t partial train loss (single batch): 0.960291
# \t partial train loss (single batch): 0.964261
# \t partial train loss (single batch): 0.962050
# \t partial train loss (single batch): 0.957107
# \t partial train loss (single batch): 0.962702
# \t partial train loss (single batch): 0.964255
# \t partial train loss (single batch): 0.964836
# \t partial train loss (single batch): 0.964079
# \t partial train loss (single batch): 0.964093
# \t partial train loss (single batch): 0.965581
# \t partial train loss (single batch): 0.964429
# \t partial train loss (single batch): 0.963820
# \t partial train loss (single batch): 0.964307
# \t partial train loss (single batch): 0.959060
# \t partial train loss (single batch): 0.962379
# \t partial train loss (single batch): 0.964324
# \t partial train loss (single batch): 0.963465
# \t partial train loss (single batch): 0.964298
# \t partial train loss (single batch): 0.962300
# \t partial train loss (single batch): 0.962238
# \t partial train loss (single batch): 0.965866
# \t partial train loss (single batch): 0.964732
# \t partial train loss (single batch): 0.962935
# \t partial train loss (single batch): 0.965226
# \t partial train loss (single batch): 0.964831
# \t partial train loss (single batch): 0.965849
# \t partial train loss (single batch): 0.961102
# \t partial train loss (single batch): 0.962477
# \t partial train loss (single batch): 0.959916
# \t partial train loss (single batch): 0.959095
# \t partial train loss (single batch): 0.960653
# \t partial train loss (single batch): 0.960118
# \t partial train loss (single batch): 0.962712
# \t partial train loss (single batch): 0.962806
# \t partial train loss (single batch): 0.965246
# \t partial train loss (single batch): 0.958730
# \t partial train loss (single batch): 0.959942
# \t partial train loss (single batch): 0.962163
# \t partial train loss (single batch): 0.960427
# \t partial train loss (single batch): 0.959766
# \t partial train loss (single batch): 0.960622
# \t partial train loss (single batch): 0.958803
# \t partial train loss (single batch): 0.963898
# \t partial train loss (single batch): 0.963639
# \t partial train loss (single batch): 0.959483
# \t partial train loss (single batch): 0.958053
# \t partial train loss (single batch): 0.961318
# \t partial train loss (single batch): 0.961462
# \t partial train loss (single batch): 0.954616
# \t partial train loss (single batch): 0.959408
# \t partial train loss (single batch): 0.954212
# \t partial train loss (single batch): 0.957392
# \t partial train loss (single batch): 0.962685
# \t partial train loss (single batch): 0.960241
# \t partial train loss (single batch): 0.958651
# \t partial train loss (single batch): 0.958649
# \t partial train loss (single batch): 0.960985
# \t partial train loss (single batch): 0.961110
# \t partial train loss (single batch): 0.959197
# \t partial train loss (single batch): 0.960458
# \t partial train loss (single batch): 0.958120
# \t partial train loss (single batch): 0.957626
# \t partial train loss (single batch): 0.956502
# \n EPOCH 3/20 \t train loss 0.969 \t val loss 0.960
# \t partial train loss (single batch): 0.962579
# \t partial train loss (single batch): 0.957910
# \t partial train loss (single batch): 0.959521
# \t partial train loss (single batch): 0.958535
# \t partial train loss (single batch): 0.959878
# \t partial train loss (single batch): 0.955672
# \t partial train loss (single batch): 0.961788
# \t partial train loss (single batch): 0.957729
# \t partial train loss (single batch): 0.955609
# \t partial train loss (single batch): 0.959662
# \t partial train loss (single batch): 0.956945
# \t partial train loss (single batch): 0.960708
# \t partial train loss (single batch): 0.955591
# \t partial train loss (single batch): 0.956789
# \t partial train loss (single batch): 0.954614
# \t partial train loss (single batch): 0.960600
# \t partial train loss (single batch): 0.960223
# \t partial train loss (single batch): 0.958012
# \t partial train loss (single batch): 0.960377
# \t partial train loss (single batch): 0.956100
# \t partial train loss (single batch): 0.955486
# \t partial train loss (single batch): 0.955702
# \t partial train loss (single batch): 0.958811
# \t partial train loss (single batch): 0.958168
# \t partial train loss (single batch): 0.960331
# \t partial train loss (single batch): 0.956506
# \t partial train loss (single batch): 0.955923
# \t partial train loss (single batch): 0.958483
# \t partial train loss (single batch): 0.956987
# \t partial train loss (single batch): 0.957303
# \t partial train loss (single batch): 0.959942
# \t partial train loss (single batch): 0.957436
# \t partial train loss (single batch): 0.956894
# \t partial train loss (single batch): 0.955842
# \t partial train loss (single batch): 0.958578
# \t partial train loss (single batch): 0.958930
# \t partial train loss (single batch): 0.957623
# \t partial train loss (single batch): 0.956298
# \t partial train loss (single batch): 0.955957
# \t partial train loss (single batch): 0.956901
# \t partial train loss (single batch): 0.952956
# \t partial train loss (single batch): 0.956545
# \t partial train loss (single batch): 0.955653
# \t partial train loss (single batch): 0.953272
# \t partial train loss (single batch): 0.958677
# \t partial train loss (single batch): 0.958298
# \t partial train loss (single batch): 0.954941
# \t partial train loss (single batch): 0.958073
# \t partial train loss (single batch): 0.954390
# \t partial train loss (single batch): 0.956172
# \t partial train loss (single batch): 0.956560
# \t partial train loss (single batch): 0.957033
# \t partial train loss (single batch): 0.954381
# \t partial train loss (single batch): 0.955773
# \t partial train loss (single batch): 0.958597
# \t partial train loss (single batch): 0.958613
# \t partial train loss (single batch): 0.958626
# \t partial train loss (single batch): 0.954561
# \t partial train loss (single batch): 0.956023
# \t partial train loss (single batch): 0.955480
# \t partial train loss (single batch): 0.957267
# \t partial train loss (single batch): 0.956037
# \t partial train loss (single batch): 0.954115
# \t partial train loss (single batch): 0.956500
# \t partial train loss (single batch): 0.958202
# \t partial train loss (single batch): 0.953861
# \t partial train loss (single batch): 0.955814
# \t partial train loss (single batch): 0.958582
# \t partial train loss (single batch): 0.957076
# \t partial train loss (single batch): 0.958505
# \t partial train loss (single batch): 0.955394
# \t partial train loss (single batch): 0.955652
# \t partial train loss (single batch): 0.955201
# \t partial train loss (single batch): 0.955265
# \t partial train loss (single batch): 0.953259
# \t partial train loss (single batch): 0.953365
# \t partial train loss (single batch): 0.955154
# \t partial train loss (single batch): 0.952798
# \t partial train loss (single batch): 0.954425
# \t partial train loss (single batch): 0.952940
# \t partial train loss (single batch): 0.957107
# \t partial train loss (single batch): 0.950659
# \t partial train loss (single batch): 0.957280
# \t partial train loss (single batch): 0.953290
# \t partial train loss (single batch): 0.954911
# \t partial train loss (single batch): 0.954394
# \t partial train loss (single batch): 0.954441
# \t partial train loss (single batch): 0.955237
# \t partial train loss (single batch): 0.951473
# \t partial train loss (single batch): 0.959959
# \t partial train loss (single batch): 0.955025
# \t partial train loss (single batch): 0.952641
# \t partial train loss (single batch): 0.954275
# \t partial train loss (single batch): 0.952229
# \t partial train loss (single batch): 0.953736
# \t partial train loss (single batch): 0.956411
# \t partial train loss (single batch): 0.952623
# \t partial train loss (single batch): 0.960445
# \t partial train loss (single batch): 0.956007
# \t partial train loss (single batch): 0.956555
# \t partial train loss (single batch): 0.954651
# \t partial train loss (single batch): 0.956752
# \t partial train loss (single batch): 0.953853
# \t partial train loss (single batch): 0.953323
# \t partial train loss (single batch): 0.952111
# \t partial train loss (single batch): 0.955951
# \t partial train loss (single batch): 0.955273
# \t partial train loss (single batch): 0.954301
# \t partial train loss (single batch): 0.952932
# \t partial train loss (single batch): 0.954585
# \t partial train loss (single batch): 0.952237
# \t partial train loss (single batch): 0.955841
# \t partial train loss (single batch): 0.954646
# \t partial train loss (single batch): 0.953744
# \t partial train loss (single batch): 0.950347
# \t partial train loss (single batch): 0.952167
# \t partial train loss (single batch): 0.950940
# \t partial train loss (single batch): 0.950319
# \t partial train loss (single batch): 0.949608
# \t partial train loss (single batch): 0.953068
# \t partial train loss (single batch): 0.951394
# \t partial train loss (single batch): 0.953188
# \t partial train loss (single batch): 0.952667
# \t partial train loss (single batch): 0.952511
# \t partial train loss (single batch): 0.952203
# \t partial train loss (single batch): 0.948620
# \t partial train loss (single batch): 0.951953
# \t partial train loss (single batch): 0.951284
# \t partial train loss (single batch): 0.946145
# \t partial train loss (single batch): 0.950287
# \t partial train loss (single batch): 0.954027
# \t partial train loss (single batch): 0.953835
# \t partial train loss (single batch): 0.950948
# \t partial train loss (single batch): 0.954282
# \t partial train loss (single batch): 0.955559
# \t partial train loss (single batch): 0.955927
# \t partial train loss (single batch): 0.952215
# \t partial train loss (single batch): 0.952245
# \t partial train loss (single batch): 0.947977
# \t partial train loss (single batch): 0.950603
# \t partial train loss (single batch): 0.954621
# \t partial train loss (single batch): 0.951330
# \t partial train loss (single batch): 0.952786
# \t partial train loss (single batch): 0.951780
# \t partial train loss (single batch): 0.950544
# \t partial train loss (single batch): 0.954005
# \t partial train loss (single batch): 0.952752
# \t partial train loss (single batch): 0.953146
# \t partial train loss (single batch): 0.954980
# \t partial train loss (single batch): 0.953020
# \t partial train loss (single batch): 0.955282
# \t partial train loss (single batch): 0.951743
# \t partial train loss (single batch): 0.949604
# \t partial train loss (single batch): 0.950016
# \t partial train loss (single batch): 0.950905
# \t partial train loss (single batch): 0.951802
# \t partial train loss (single batch): 0.950014
# \t partial train loss (single batch): 0.951422
# \t partial train loss (single batch): 0.951422
# \t partial train loss (single batch): 0.952522
# \t partial train loss (single batch): 0.949555
# \t partial train loss (single batch): 0.948908
# \t partial train loss (single batch): 0.954849
# \t partial train loss (single batch): 0.950249
# \t partial train loss (single batch): 0.949292
# \t partial train loss (single batch): 0.953158
# \t partial train loss (single batch): 0.951226
# \t partial train loss (single batch): 0.953014
# \t partial train loss (single batch): 0.953609
# \t partial train loss (single batch): 0.948090
# \t partial train loss (single batch): 0.950021
# \t partial train loss (single batch): 0.952787
# \t partial train loss (single batch): 0.951710
# \t partial train loss (single batch): 0.945871
# \t partial train loss (single batch): 0.950933
# \t partial train loss (single batch): 0.946113
# \t partial train loss (single batch): 0.949947
# \t partial train loss (single batch): 0.954282
# \t partial train loss (single batch): 0.952338
# \t partial train loss (single batch): 0.951241
# \t partial train loss (single batch): 0.951316
# \t partial train loss (single batch): 0.949844
# \t partial train loss (single batch): 0.952283
# \t partial train loss (single batch): 0.951502
# \t partial train loss (single batch): 0.950080
# \t partial train loss (single batch): 0.950928
# \t partial train loss (single batch): 0.947709
# \t partial train loss (single batch): 0.945581
# \n EPOCH 4/20 \t train loss 0.954 \t val loss 0.951
# \t partial train loss (single batch): 0.953509
# \t partial train loss (single batch): 0.950427
# \t partial train loss (single batch): 0.951168
# \t partial train loss (single batch): 0.950224
# \t partial train loss (single batch): 0.946700
# \t partial train loss (single batch): 0.947756
# \t partial train loss (single batch): 0.951709
# \t partial train loss (single batch): 0.947540
# \t partial train loss (single batch): 0.948349
# \t partial train loss (single batch): 0.949939
# \t partial train loss (single batch): 0.948655
# \t partial train loss (single batch): 0.952423
# \t partial train loss (single batch): 0.946982
# \t partial train loss (single batch): 0.947490
# \t partial train loss (single batch): 0.948646
# \t partial train loss (single batch): 0.951803
# \t partial train loss (single batch): 0.949501
# \t partial train loss (single batch): 0.949090
# \t partial train loss (single batch): 0.952234
# \t partial train loss (single batch): 0.946504
# \t partial train loss (single batch): 0.946608
# \t partial train loss (single batch): 0.946546
# \t partial train loss (single batch): 0.950800
# \t partial train loss (single batch): 0.950933
# \t partial train loss (single batch): 0.949792
# \t partial train loss (single batch): 0.945674
# \t partial train loss (single batch): 0.948729
# \t partial train loss (single batch): 0.949288
# \t partial train loss (single batch): 0.948546
# \t partial train loss (single batch): 0.949678
# \t partial train loss (single batch): 0.951857
# \t partial train loss (single batch): 0.950606
# \t partial train loss (single batch): 0.946652
# \t partial train loss (single batch): 0.948433
# \t partial train loss (single batch): 0.951747
# \t partial train loss (single batch): 0.950836
# \t partial train loss (single batch): 0.951184
# \t partial train loss (single batch): 0.949028
# \t partial train loss (single batch): 0.949538
# \t partial train loss (single batch): 0.949939
# \t partial train loss (single batch): 0.947927
# \t partial train loss (single batch): 0.948639
# \t partial train loss (single batch): 0.948084
# \t partial train loss (single batch): 0.946281
# \t partial train loss (single batch): 0.951223
# \t partial train loss (single batch): 0.950642
# \t partial train loss (single batch): 0.946337
# \t partial train loss (single batch): 0.950511
# \t partial train loss (single batch): 0.946417
# \t partial train loss (single batch): 0.946153
# \t partial train loss (single batch): 0.949931
# \t partial train loss (single batch): 0.948620
# \t partial train loss (single batch): 0.946693
# \t partial train loss (single batch): 0.950234
# \t partial train loss (single batch): 0.949934
# \t partial train loss (single batch): 0.949846
# \t partial train loss (single batch): 0.951547
# \t partial train loss (single batch): 0.948358
# \t partial train loss (single batch): 0.947295
# \t partial train loss (single batch): 0.947326
# \t partial train loss (single batch): 0.948812
# \t partial train loss (single batch): 0.947393
# \t partial train loss (single batch): 0.946104
# \t partial train loss (single batch): 0.946677
# \t partial train loss (single batch): 0.950543
# \t partial train loss (single batch): 0.947876
# \t partial train loss (single batch): 0.950582
# \t partial train loss (single batch): 0.951041
# \t partial train loss (single batch): 0.952367
# \t partial train loss (single batch): 0.950764
# \t partial train loss (single batch): 0.947652
# \t partial train loss (single batch): 0.949788
# \t partial train loss (single batch): 0.949039
# \t partial train loss (single batch): 0.948047
# \t partial train loss (single batch): 0.945862
# \t partial train loss (single batch): 0.946531
# \t partial train loss (single batch): 0.947777
# \t partial train loss (single batch): 0.946398
# \t partial train loss (single batch): 0.946375
# \t partial train loss (single batch): 0.949595
# \t partial train loss (single batch): 0.950398
# \t partial train loss (single batch): 0.944633
# \t partial train loss (single batch): 0.949269
# \t partial train loss (single batch): 0.946724
# \t partial train loss (single batch): 0.947703
# \t partial train loss (single batch): 0.945970
# \t partial train loss (single batch): 0.949283
# \t partial train loss (single batch): 0.947920
# \t partial train loss (single batch): 0.943927
# \t partial train loss (single batch): 0.952256
# \t partial train loss (single batch): 0.949028
# \t partial train loss (single batch): 0.945977
# \t partial train loss (single batch): 0.948462
# \t partial train loss (single batch): 0.944593
# \t partial train loss (single batch): 0.945452
# \t partial train loss (single batch): 0.949708
# \t partial train loss (single batch): 0.944835
# \t partial train loss (single batch): 0.952308
# \t partial train loss (single batch): 0.949281
# \t partial train loss (single batch): 0.950115
# \t partial train loss (single batch): 0.948780
# \t partial train loss (single batch): 0.950449
# \t partial train loss (single batch): 0.947380
# \t partial train loss (single batch): 0.949354
# \t partial train loss (single batch): 0.942868
# \t partial train loss (single batch): 0.948870
# \t partial train loss (single batch): 0.948679
# \t partial train loss (single batch): 0.946662
# \t partial train loss (single batch): 0.946370
# \t partial train loss (single batch): 0.949687
# \t partial train loss (single batch): 0.946592
# \t partial train loss (single batch): 0.949780
# \t partial train loss (single batch): 0.948419
# \t partial train loss (single batch): 0.947016
# \t partial train loss (single batch): 0.944108
# \t partial train loss (single batch): 0.947535
# \t partial train loss (single batch): 0.946059
# \t partial train loss (single batch): 0.942874
# \t partial train loss (single batch): 0.942958
# \t partial train loss (single batch): 0.945981
# \t partial train loss (single batch): 0.945486
# \t partial train loss (single batch): 0.948886
# \t partial train loss (single batch): 0.947925
# \t partial train loss (single batch): 0.945016
# \t partial train loss (single batch): 0.946691
# \t partial train loss (single batch): 0.943370
# \t partial train loss (single batch): 0.948397
# \t partial train loss (single batch): 0.946721
# \t partial train loss (single batch): 0.941328
# \t partial train loss (single batch): 0.944866
# \t partial train loss (single batch): 0.946370
# \t partial train loss (single batch): 0.948400
# \t partial train loss (single batch): 0.945813
# \t partial train loss (single batch): 0.948269
# \t partial train loss (single batch): 0.947841
# \t partial train loss (single batch): 0.948183
# \t partial train loss (single batch): 0.948101
# \t partial train loss (single batch): 0.947929
# \t partial train loss (single batch): 0.942553
# \t partial train loss (single batch): 0.946266
# \t partial train loss (single batch): 0.946852
# \t partial train loss (single batch): 0.945814
# \t partial train loss (single batch): 0.946954
# \t partial train loss (single batch): 0.944457
# \t partial train loss (single batch): 0.945574
# \t partial train loss (single batch): 0.948272
# \t partial train loss (single batch): 0.947400
# \t partial train loss (single batch): 0.945862
# \t partial train loss (single batch): 0.949585
# \t partial train loss (single batch): 0.947664
# \t partial train loss (single batch): 0.947119
# \t partial train loss (single batch): 0.947989
# \t partial train loss (single batch): 0.945483
# \t partial train loss (single batch): 0.943562
# \t partial train loss (single batch): 0.943281
# \t partial train loss (single batch): 0.946320
# \t partial train loss (single batch): 0.944378
# \t partial train loss (single batch): 0.946029
# \t partial train loss (single batch): 0.946386
# \t partial train loss (single batch): 0.947157
# \t partial train loss (single batch): 0.942750
# \t partial train loss (single batch): 0.943819
# \t partial train loss (single batch): 0.948618
# \t partial train loss (single batch): 0.944306
# \t partial train loss (single batch): 0.945139
# \t partial train loss (single batch): 0.948493
# \t partial train loss (single batch): 0.946325
# \t partial train loss (single batch): 0.948238
# \t partial train loss (single batch): 0.948787
# \t partial train loss (single batch): 0.942822
# \t partial train loss (single batch): 0.945479
# \t partial train loss (single batch): 0.948263
# \t partial train loss (single batch): 0.946845
# \t partial train loss (single batch): 0.941873
# \t partial train loss (single batch): 0.943640
# \t partial train loss (single batch): 0.941383
# \t partial train loss (single batch): 0.944803
# \t partial train loss (single batch): 0.950748
# \t partial train loss (single batch): 0.945619
# \t partial train loss (single batch): 0.945781
# \t partial train loss (single batch): 0.944940
# \t partial train loss (single batch): 0.946425
# \t partial train loss (single batch): 0.949396
# \t partial train loss (single batch): 0.946766
# \t partial train loss (single batch): 0.944572
# \t partial train loss (single batch): 0.945797
# \t partial train loss (single batch): 0.942924
# \t partial train loss (single batch): 0.941745
# \n EPOCH 5/20 \t train loss 0.948 \t val loss 0.945
# \t partial train loss (single batch): 0.947498
# \t partial train loss (single batch): 0.944849
# \t partial train loss (single batch): 0.945848
# \t partial train loss (single batch): 0.944974
# \t partial train loss (single batch): 0.944137
# \t partial train loss (single batch): 0.943660
# \t partial train loss (single batch): 0.948022
# \t partial train loss (single batch): 0.941941
# \t partial train loss (single batch): 0.943710
# \t partial train loss (single batch): 0.945011
# \t partial train loss (single batch): 0.943178
# \t partial train loss (single batch): 0.946151
# \t partial train loss (single batch): 0.938761
# \t partial train loss (single batch): 0.942633
# \t partial train loss (single batch): 0.942763
# \t partial train loss (single batch): 0.946792
# \t partial train loss (single batch): 0.945979
# \t partial train loss (single batch): 0.944307
# \t partial train loss (single batch): 0.946546
# \t partial train loss (single batch): 0.942003
# \t partial train loss (single batch): 0.942133
# \t partial train loss (single batch): 0.943032
# \t partial train loss (single batch): 0.945356
# \t partial train loss (single batch): 0.944775
# \t partial train loss (single batch): 0.944928
# \t partial train loss (single batch): 0.943625
# \t partial train loss (single batch): 0.942996
# \t partial train loss (single batch): 0.945736
# \t partial train loss (single batch): 0.944578
# \t partial train loss (single batch): 0.943764
# \t partial train loss (single batch): 0.946723
# \t partial train loss (single batch): 0.944101
# \t partial train loss (single batch): 0.942154
# \t partial train loss (single batch): 0.942439
# \t partial train loss (single batch): 0.946607
# \t partial train loss (single batch): 0.945892
# \t partial train loss (single batch): 0.944368
# \t partial train loss (single batch): 0.943688
# \t partial train loss (single batch): 0.941814
# \t partial train loss (single batch): 0.945212
# \t partial train loss (single batch): 0.940540
# \t partial train loss (single batch): 0.944936
# \t partial train loss (single batch): 0.942548
# \t partial train loss (single batch): 0.939956
# \t partial train loss (single batch): 0.946813
# \t partial train loss (single batch): 0.946466
# \t partial train loss (single batch): 0.941574
# \t partial train loss (single batch): 0.946494
# \t partial train loss (single batch): 0.939588
# \t partial train loss (single batch): 0.942567
# \t partial train loss (single batch): 0.944354
# \t partial train loss (single batch): 0.945706
# \t partial train loss (single batch): 0.942921
# \t partial train loss (single batch): 0.944259
# \t partial train loss (single batch): 0.945227
# \t partial train loss (single batch): 0.947622
# \t partial train loss (single batch): 0.946047
# \t partial train loss (single batch): 0.943734
# \t partial train loss (single batch): 0.945180
# \t partial train loss (single batch): 0.942779
# \t partial train loss (single batch): 0.944612
# \t partial train loss (single batch): 0.943252
# \t partial train loss (single batch): 0.941125
# \t partial train loss (single batch): 0.943965
# \t partial train loss (single batch): 0.947766
# \t partial train loss (single batch): 0.943240
# \t partial train loss (single batch): 0.943322
# \t partial train loss (single batch): 0.946753
# \t partial train loss (single batch): 0.946994
# \t partial train loss (single batch): 0.944663
# \t partial train loss (single batch): 0.943648
# \t partial train loss (single batch): 0.944726
# \t partial train loss (single batch): 0.943106
# \t partial train loss (single batch): 0.941974
# \t partial train loss (single batch): 0.941596
# ...
# \t partial train loss (single batch): 0.922741
# \t partial train loss (single batch): 0.926962
# \t partial train loss (single batch): 0.920533
# \t partial train loss (single batch): 0.923396
# \t partial train loss (single batch): 0.922101
# \t partial train loss (single batch): 0.920875
# \t partial train loss (single batch): 0.925775
# \t partial train loss (single batch): 0.925824
# \t partial train loss (single batch): 0.920754
# \t partial train loss (single batch): 0.925227
# \t partial train loss (single batch): 0.920200
# \t partial train loss (single batch): 0.922162
# \t partial train loss (single batch): 0.924946
# \t partial train loss (single batch): 0.924361
# \t partial train loss (single batch): 0.923223
# \t partial train loss (single batch): 0.922416
# \t partial train loss (single batch): 0.924086
# \t partial train loss (single batch): 0.927034
# \t partial train loss (single batch): 0.927106
# \t partial train loss (single batch): 0.923720
# \t partial train loss (single batch): 0.922931
# \t partial train loss (single batch): 0.924455
# \t partial train loss (single batch): 0.925272
# \t partial train loss (single batch): 0.922824
# \t partial train loss (single batch): 0.922225
# \t partial train loss (single batch): 0.925440
# \t partial train loss (single batch): 0.928955
# \t partial train loss (single batch): 0.925470
# \t partial train loss (single batch): 0.925842
# \t partial train loss (single batch): 0.927831
# \t partial train loss (single batch): 0.928599
# \t partial train loss (single batch): 0.926571
# \t partial train loss (single batch): 0.925203
# \t partial train loss (single batch): 0.924934
# \t partial train loss (single batch): 0.925821
# \t partial train loss (single batch): 0.924279
# \t partial train loss (single batch): 0.920175
# \t partial train loss (single batch): 0.923665
# \t partial train loss (single batch): 0.924061
# \t partial train loss (single batch): 0.923043
# \t partial train loss (single batch): 0.924090
# \t partial train loss (single batch): 0.923997
# \t partial train loss (single batch): 0.926949
# \t partial train loss (single batch): 0.918019
# \t partial train loss (single batch): 0.926236
# \t partial train loss (single batch): 0.921551
# \t partial train loss (single batch): 0.924239
# \t partial train loss (single batch): 0.925104
# \t partial train loss (single batch): 0.926891
# \t partial train loss (single batch): 0.925197
# \t partial train loss (single batch): 0.920194
# \t partial train loss (single batch): 0.928943
# \t partial train loss (single batch): 0.925630
# \t partial train loss (single batch): 0.922237
# \t partial train loss (single batch): 0.927048
# \t partial train loss (single batch): 0.921483
# \t partial train loss (single batch): 0.921625
# \t partial train loss (single batch): 0.925747
# \t partial train loss (single batch): 0.920075
# \t partial train loss (single batch): 0.930490
# \t partial train loss (single batch): 0.926072
# \t partial train loss (single batch): 0.926781
# \t partial train loss (single batch): 0.926030
# \t partial train loss (single batch): 0.926171
# \t partial train loss (single batch): 0.925989
# \t partial train loss (single batch): 0.925897
# \t partial train loss (single batch): 0.919928
# \t partial train loss (single batch): 0.923844
# \t partial train loss (single batch): 0.923345
# \t partial train loss (single batch): 0.922597
# \t partial train loss (single batch): 0.922165
# \t partial train loss (single batch): 0.924838
# \t partial train loss (single batch): 0.922182
# \t partial train loss (single batch): 0.927489
# \t partial train loss (single batch): 0.925065
# \t partial train loss (single batch): 0.923146
# \t partial train loss (single batch): 0.922988
# \t partial train loss (single batch): 0.924351
# \t partial train loss (single batch): 0.921202
# \t partial train loss (single batch): 0.921501
# \t partial train loss (single batch): 0.919583
# \t partial train loss (single batch): 0.922823
# \t partial train loss (single batch): 0.924046
# \t partial train loss (single batch): 0.925182
# \t partial train loss (single batch): 0.923092
# \t partial train loss (single batch): 0.923017
# \t partial train loss (single batch): 0.924131
# \t partial train loss (single batch): 0.919235
# \t partial train loss (single batch): 0.923959
# \t partial train loss (single batch): 0.922237
# \t partial train loss (single batch): 0.919890
# \t partial train loss (single batch): 0.921806
# \t partial train loss (single batch): 0.923575
# \t partial train loss (single batch): 0.925029
# \t partial train loss (single batch): 0.924920
# \t partial train loss (single batch): 0.924216
# \t partial train loss (single batch): 0.927040
# \t partial train loss (single batch): 0.926873
# \t partial train loss (single batch): 0.924244
# \t partial train loss (single batch): 0.925211
# \t partial train loss (single batch): 0.921285
# \t partial train loss (single batch): 0.920806
# \t partial train loss (single batch): 0.924173
# \t partial train loss (single batch): 0.923930
# \t partial train loss (single batch): 0.924337
# \t partial train loss (single batch): 0.923964
# \t partial train loss (single batch): 0.923596
# \t partial train loss (single batch): 0.925237
# \t partial train loss (single batch): 0.925413
# \t partial train loss (single batch): 0.923310
# \t partial train loss (single batch): 0.927303
# \t partial train loss (single batch): 0.926523
# \t partial train loss (single batch): 0.925512
# \t partial train loss (single batch): 0.924847
# \t partial train loss (single batch): 0.921884
# \t partial train loss (single batch): 0.922007
# \t partial train loss (single batch): 0.920896
# \t partial train loss (single batch): 0.922918
# \t partial train loss (single batch): 0.920448
# \t partial train loss (single batch): 0.923938
# \t partial train loss (single batch): 0.924742
# \t partial train loss (single batch): 0.929148
# \t partial train loss (single batch): 0.919733
# \t partial train loss (single batch): 0.922895
# \t partial train loss (single batch): 0.925244
# \t partial train loss (single batch): 0.922086
# \t partial train loss (single batch): 0.923055
# \t partial train loss (single batch): 0.925533
# \t partial train loss (single batch): 0.926805
# \t partial train loss (single batch): 0.924344
# \t partial train loss (single batch): 0.925401
# \t partial train loss (single batch): 0.920371
# \t partial train loss (single batch): 0.922797
# \t partial train loss (single batch): 0.924893
# \t partial train loss (single batch): 0.925825
# \t partial train loss (single batch): 0.920126
# \t partial train loss (single batch): 0.922065
# \t partial train loss (single batch): 0.920452
# \t partial train loss (single batch): 0.923185
# \t partial train loss (single batch): 0.927766
# \t partial train loss (single batch): 0.922678
# \t partial train loss (single batch): 0.922071
# \t partial train loss (single batch): 0.922736
# \t partial train loss (single batch): 0.924860
# \t partial train loss (single batch): 0.924166
# \t partial train loss (single batch): 0.923972
# \t partial train loss (single batch): 0.923817
# \t partial train loss (single batch): 0.924917
# \t partial train loss (single batch): 0.920173
# \t partial train loss (single batch): 0.919095
# \n EPOCH 19/20 \t train loss 0.924 \t val loss 0.924
# \t partial train loss (single batch): 0.927221
# \t partial train loss (single batch): 0.922910
# \t partial train loss (single batch): 0.923759
# \t partial train loss (single batch): 0.922719
# \t partial train loss (single batch): 0.924781
# \t partial train loss (single batch): 0.922663
# \t partial train loss (single batch): 0.925992
# \t partial train loss (single batch): 0.920763
# \t partial train loss (single batch): 0.922144
# \t partial train loss (single batch): 0.924708
# \t partial train loss (single batch): 0.922536
# \t partial train loss (single batch): 0.926452
# \t partial train loss (single batch): 0.916995
# \t partial train loss (single batch): 0.920543
# \t partial train loss (single batch): 0.920160
# \t partial train loss (single batch): 0.923787
# \t partial train loss (single batch): 0.925658
# \t partial train loss (single batch): 0.922980
# \t partial train loss (single batch): 0.926612
# \t partial train loss (single batch): 0.922269
# \t partial train loss (single batch): 0.922216
# \t partial train loss (single batch): 0.919409
# \t partial train loss (single batch): 0.924048
# \t partial train loss (single batch): 0.925335
# \t partial train loss (single batch): 0.925099
# \t partial train loss (single batch): 0.920166
# \t partial train loss (single batch): 0.922266
# \t partial train loss (single batch): 0.923682
# \t partial train loss (single batch): 0.921914
# \t partial train loss (single batch): 0.923313
# \t partial train loss (single batch): 0.926754
# \t partial train loss (single batch): 0.924242
# \t partial train loss (single batch): 0.920978
# \t partial train loss (single batch): 0.921775
# \t partial train loss (single batch): 0.925833
# \t partial train loss (single batch): 0.924859
# \t partial train loss (single batch): 0.924428
# \t partial train loss (single batch): 0.923190
# \t partial train loss (single batch): 0.922572
# \t partial train loss (single batch): 0.926627
# \t partial train loss (single batch): 0.920503
# \t partial train loss (single batch): 0.923419
# \t partial train loss (single batch): 0.922224
# \t partial train loss (single batch): 0.921033
# \t partial train loss (single batch): 0.924803
# \t partial train loss (single batch): 0.926613
# \t partial train loss (single batch): 0.922069
# \t partial train loss (single batch): 0.923572
# \t partial train loss (single batch): 0.919941
# \t partial train loss (single batch): 0.920956
# \t partial train loss (single batch): 0.923969
# \t partial train loss (single batch): 0.924582
# \t partial train loss (single batch): 0.921274
# \t partial train loss (single batch): 0.923104
# \t partial train loss (single batch): 0.922439
# \t partial train loss (single batch): 0.926443
# \t partial train loss (single batch): 0.927169
# \t partial train loss (single batch): 0.922619
# \t partial train loss (single batch): 0.924159
# \t partial train loss (single batch): 0.921572
# \t partial train loss (single batch): 0.923532
# \t partial train loss (single batch): 0.923209
# \t partial train loss (single batch): 0.922581
# \t partial train loss (single batch): 0.925046
# \t partial train loss (single batch): 0.927269
# \t partial train loss (single batch): 0.921584
# \t partial train loss (single batch): 0.925175
# \t partial train loss (single batch): 0.927500
# \t partial train loss (single batch): 0.926157
# \t partial train loss (single batch): 0.925079
# \t partial train loss (single batch): 0.923799
# \t partial train loss (single batch): 0.923738
# \t partial train loss (single batch): 0.925315
# \t partial train loss (single batch): 0.922457
# \t partial train loss (single batch): 0.919523
# \t partial train loss (single batch): 0.921519
# \t partial train loss (single batch): 0.922734
# \t partial train loss (single batch): 0.920951
# \t partial train loss (single batch): 0.922249
# \t partial train loss (single batch): 0.922733
# \t partial train loss (single batch): 0.924939
# \t partial train loss (single batch): 0.916971
# \t partial train loss (single batch): 0.925412
# \t partial train loss (single batch): 0.923479
# \t partial train loss (single batch): 0.924061
# \t partial train loss (single batch): 0.923235
# \t partial train loss (single batch): 0.924327
# \t partial train loss (single batch): 0.921882
# \t partial train loss (single batch): 0.919514
# \t partial train loss (single batch): 0.927783
# \t partial train loss (single batch): 0.924196
# \t partial train loss (single batch): 0.922549
# \t partial train loss (single batch): 0.924940
# \t partial train loss (single batch): 0.918950
# \t partial train loss (single batch): 0.921087
# \t partial train loss (single batch): 0.925729
# \t partial train loss (single batch): 0.921365
# \t partial train loss (single batch): 0.930098
# \t partial train loss (single batch): 0.925560
# \t partial train loss (single batch): 0.926735
# \t partial train loss (single batch): 0.923497
# \t partial train loss (single batch): 0.926267
# \t partial train loss (single batch): 0.924493
# \t partial train loss (single batch): 0.924148
# \t partial train loss (single batch): 0.918968
# \t partial train loss (single batch): 0.924703
# \t partial train loss (single batch): 0.924259
# \t partial train loss (single batch): 0.923313
# \t partial train loss (single batch): 0.922100
# \t partial train loss (single batch): 0.926004
# \t partial train loss (single batch): 0.920249
# \t partial train loss (single batch): 0.925778
# \t partial train loss (single batch): 0.926954
# \t partial train loss (single batch): 0.921886
# \t partial train loss (single batch): 0.922922
# \t partial train loss (single batch): 0.924071
# \t partial train loss (single batch): 0.921763
# \t partial train loss (single batch): 0.920255
# \t partial train loss (single batch): 0.917567
# \t partial train loss (single batch): 0.923152
# \t partial train loss (single batch): 0.921509
# \t partial train loss (single batch): 0.924432
# \t partial train loss (single batch): 0.921822
# \t partial train loss (single batch): 0.922066
# \t partial train loss (single batch): 0.923697
# \t partial train loss (single batch): 0.917315
# \t partial train loss (single batch): 0.922544
# \t partial train loss (single batch): 0.921044
# \t partial train loss (single batch): 0.917941
# \t partial train loss (single batch): 0.920427
# \t partial train loss (single batch): 0.922536
# \t partial train loss (single batch): 0.924002
# \t partial train loss (single batch): 0.923987
# \t partial train loss (single batch): 0.923329
# \t partial train loss (single batch): 0.927080
# \t partial train loss (single batch): 0.925357
# \t partial train loss (single batch): 0.923142
# \t partial train loss (single batch): 0.925666
# \t partial train loss (single batch): 0.918806
# \t partial train loss (single batch): 0.921436
# \t partial train loss (single batch): 0.923258
# \t partial train loss (single batch): 0.923204
# \t partial train loss (single batch): 0.921460
# \t partial train loss (single batch): 0.923850
# \t partial train loss (single batch): 0.921525
# \t partial train loss (single batch): 0.926189
# \t partial train loss (single batch): 0.924258
# \t partial train loss (single batch): 0.923100
# \t partial train loss (single batch): 0.926521
# \t partial train loss (single batch): 0.926080
# \t partial train loss (single batch): 0.925441
# \t partial train loss (single batch): 0.924775
# \t partial train loss (single batch): 0.922441
# \t partial train loss (single batch): 0.919796
# \t partial train loss (single batch): 0.919894
# \t partial train loss (single batch): 0.923490
# \t partial train loss (single batch): 0.918778
# \t partial train loss (single batch): 0.924453
# \t partial train loss (single batch): 0.923899
# \t partial train loss (single batch): 0.925452
# \t partial train loss (single batch): 0.920153
# \t partial train loss (single batch): 0.920648
# \t partial train loss (single batch): 0.925617
# \t partial train loss (single batch): 0.920964
# \t partial train loss (single batch): 0.922082
# \t partial train loss (single batch): 0.925474
# \t partial train loss (single batch): 0.924050
# \t partial train loss (single batch): 0.924947
# \t partial train loss (single batch): 0.923313
# \t partial train loss (single batch): 0.922714
# \t partial train loss (single batch): 0.921051
# \t partial train loss (single batch): 0.922764
# \t partial train loss (single batch): 0.926864
# \t partial train loss (single batch): 0.916644
# \t partial train loss (single batch): 0.921661
# \t partial train loss (single batch): 0.918659
# \t partial train loss (single batch): 0.922068
# \t partial train loss (single batch): 0.924958
# \t partial train loss (single batch): 0.924641
# \t partial train loss (single batch): 0.922885
# \t partial train loss (single batch): 0.921511
# \t partial train loss (single batch): 0.924025
# \t partial train loss (single batch): 0.923283
# \t partial train loss (single batch): 0.922895
# \t partial train loss (single batch): 0.922148
# \t partial train loss (single batch): 0.925362
# \t partial train loss (single batch): 0.919832
# \t partial train loss (single batch): 0.916855
# \n EPOCH 20/20 \t train loss 0.923 \t val loss 0.923

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.9221481084823608

# %%
# Train and validation loss

plt.figure(figsize=(7,5))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %% [markdown]
# Під час виконання лабораторної роботи було створено автокодувальну нейронну мережу з використанням PyTorch, яка призначена для обробки зашумлених зображень цифр із набору MNIST. До вхідних зображень навмисно додавався шум, що дало змогу перевірити, як добре модель справляється з відновленням спотворених даних. Побудована мережа складалася з енкодера, що стискає зображення, та декодера, який відновлює їхній початковий вигляд. У ході навчання було досягнуто поступового зниження помилки, що свідчить про здатність моделі адаптуватися до задачі. В результаті модель успішно очищала зображення від шуму, зберігаючи основні контури цифр. Це демонструє практичну користь автокодувальників для задач попередньої обробки зображень, особливо у випадках, коли дані містять шум або інші спотворення.
